-- %% [markdown]
-- # [InventarioBDD]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [InventarioBDD]    Script Date: 28/03/2025 11:36:03 ******/
CREATE DATABASE [InventarioBDD]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'InventarioBDD', FILENAME = N'D:\Database\SQL\2022\Data\InventarioBDD.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'InventarioBDD_log', FILENAME = N'D:\Database\SQL\2022\Log\InventarioBDD_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [InventarioBDD] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [InventarioBDD].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [InventarioBDD] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [InventarioBDD] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [InventarioBDD] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [InventarioBDD] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [InventarioBDD] SET ARITHABORT OFF 
GO
ALTER DATABASE [InventarioBDD] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [InventarioBDD] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [InventarioBDD] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [InventarioBDD] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [InventarioBDD] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [InventarioBDD] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [InventarioBDD] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [InventarioBDD] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [InventarioBDD] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [InventarioBDD] SET  DISABLE_BROKER 
GO
ALTER DATABASE [InventarioBDD] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [InventarioBDD] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [InventarioBDD] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [InventarioBDD] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [InventarioBDD] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [InventarioBDD] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [InventarioBDD] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [InventarioBDD] SET RECOVERY FULL 
GO
ALTER DATABASE [InventarioBDD] SET  MULTI_USER 
GO
ALTER DATABASE [InventarioBDD] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [InventarioBDD] SET DB_CHAINING OFF 
GO
ALTER DATABASE [InventarioBDD] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [InventarioBDD] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [InventarioBDD] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [InventarioBDD] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'InventarioBDD', N'ON'
GO
ALTER DATABASE [InventarioBDD] SET QUERY_STORE = ON
GO
ALTER DATABASE [InventarioBDD] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Categorias]

-- %%
USE [InventarioBDD]
GO

-- %%
/****** Object:  Table [dbo].[Categorias]    Script Date: 28/03/2025 11:36:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categorias](
	[cat_id] [int] IDENTITY(1,1) NOT NULL,
	[cat_name] [nvarchar](50) NOT NULL,
	[cat_details] [nvarchar](50) NOT NULL,
	[cat_group] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Categorias] PRIMARY KEY CLUSTERED 
(
	[cat_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Estados]

-- %%
/****** Object:  Table [dbo].[Estados]    Script Date: 28/03/2025 11:36:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Estados](
	[est_id] [int] IDENTITY(1,1) NOT NULL,
	[est_name] [nvarchar](50) NOT NULL,
	[est_details] [nvarchar](50) NULL,
	[est_color] [nvarchar](50) NULL,
 CONSTRAINT [PK_Estados] PRIMARY KEY CLUSTERED 
(
	[est_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Logs]

-- %%
/****** Object:  Table [dbo].[Logs]    Script Date: 28/03/2025 11:36:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Logs](
	[log_id] [int] IDENTITY(1,1) NOT NULL,
	[log_TargetSiteName] [nvarchar](max) NOT NULL,
	[log_GetTypeName] [nvarchar](max) NOT NULL,
	[log_Message] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_Logs] PRIMARY KEY CLUSTERED 
(
	[log_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Productos]

-- %%
/****** Object:  Table [dbo].[Productos]    Script Date: 28/03/2025 11:36:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Productos](
	[prod_id] [int] IDENTITY(1,1) NOT NULL,
	[prod_name] [nvarchar](50) NOT NULL,
	[prod_details] [nvarchar](50) NOT NULL,
	[cat_id] [int] NOT NULL,
	[prod_image] [nvarchar](max) NOT NULL,
	[prod_price] [decimal](18, 2) NOT NULL,
	[prod_stock] [int] NOT NULL,
	[est_id] [int] NOT NULL,
 CONSTRAINT [PK_Productos] PRIMARY KEY CLUSTERED 
(
	[prod_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Productos_Categorias]

-- %%
ALTER TABLE [dbo].[Productos]  WITH CHECK ADD  CONSTRAINT [FK_Productos_Categorias] FOREIGN KEY([cat_id])
REFERENCES [dbo].[Categorias] ([cat_id])
GO
ALTER TABLE [dbo].[Productos] CHECK CONSTRAINT [FK_Productos_Categorias]
GO

-- %% [markdown]
-- # [FK_Productos_Estados]

-- %%
ALTER TABLE [dbo].[Productos]  WITH CHECK ADD  CONSTRAINT [FK_Productos_Estados] FOREIGN KEY([est_id])
REFERENCES [dbo].[Estados] ([est_id])
GO
ALTER TABLE [dbo].[Productos] CHECK CONSTRAINT [FK_Productos_Estados]
GO

-- %% [markdown]
-- # [InventarioBDD]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [InventarioBDD] SET  READ_WRITE 
GO
